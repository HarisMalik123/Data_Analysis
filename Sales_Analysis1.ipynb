# %%
#installing pandas 
#In Python, Pandas is a powerful library for data manipulation and analysis
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: C:\Users\Haris\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
##importing pandas 
import pandas as pd

# %%
#Reading Sales.Csv File
pd.read_csv('sales.csv')
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
##storing it in variable
data=pd.read_csv('sales.csv')

# %%
data
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
## this expression will return a new DataFrame containing only the rows where the 'Gender' column has the value 'Male'.
data.query('Gender=="Male"')
# Out:
#      Invoice ID       Date   Time Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46   Male   Brookfield  NewYork    Yes
# 2     411909258  2/25/2018  13:33   Male  Water tower  Chicago     No
# 5     263634050   3/9/2018  17:55   Male   Brookfield  NewYork    Yes
# 6      99646662   3/4/2018  13:21   Male  Water tower  Chicago     No
# 7     188869875   3/8/2018  13:24   Male    Park lane   Dallas     No
# ..          ...        ...    ...    ...          ...      ...    ...
# 992   927909627   3/2/2018  13:35   Male   Brookfield  NewYork     No
# 994   446582560  1/31/2018  19:00   Male  Water tower  Chicago     No
# 995   818829599  3/26/2018  11:19   Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17   Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44   Male   Brookfield  NewYork     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
## data.sum() this calculate the sum of each column in our data frame and it will return series where each index represent a particular columns
data.sum()
# Out:
# Invoice ID                                         494493053341
# Date          1/25/20183/19/20182/25/20181/22/20182/18/20183...
# Time          16:4616:4813:3313:3815:3117:5513:2113:2415:331...
# Gender        MaleFemaleMaleFemaleFemaleMaleMaleMaleMaleFema...
# Location      BrookfieldWater towerWater towerPark lanePark ...
# City          NewYorkChicagoChicagoDallasDallasNewYorkChicag...
# Member        YesYesNoYesNoYesNoNoYesNoNoNoNoYesNoYesYesYesY...
# Category      GroceriesFashionClothingSportingBooksClothingC...
# Price                                                     51112
# Quantity                                                   4059
# Total                                                    207788
# Payment       CashCardCashGpayCashGpayCashCashCardCashGpayCa...
# Rating                                                     2972
# dtype: object

# %%
##If we Mention columns name it will return sum of all values in that particular column
data.sum()['Total']
# Out:
# 207788

# %%
data.max()
# Out:
# Invoice ID      999665753
# Date             3/9/2018
# Time                20:59
# Gender               Male
# Location      Water tower
# City              NewYork
# Member                Yes
# Category         Sporting
# Price                 100
# Quantity                7
# Total                 693
# Payment              Gpay
# Rating                  5
# dtype: object

# %%
 ##it will return maximum values in each column but if we mention data.max()['ColumnName'] it will return maximum from it
data.max()
# Out:
# Invoice ID      999665753
# Date             3/9/2018
# Time                20:59
# Gender               Male
# Location      Water tower
# City              NewYork
# Member                Yes
# Category         Sporting
# Price                 100
# Quantity                7
# Total                 693
# Payment              Gpay
# Rating                  5
# dtype: object

# %%
data.max()['Total']
# Out:
# 693

# %%
## it is used to filter a DataFrame named data to include only the rows where the value in the 'Total' column is equal to the maximum value in the entire 'Total' column.
## it will create a bolean mask 
data[data['Total']==data.max()['Total']]
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 47    315624039  3/30/2018  19:45  Female  Water tower  Chicago    Yes
# 679   270918350  3/27/2018  13:21  Female    Park lane   Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 47   Groceries     99         7    693    Gpay       3
# 679  Groceries     99         7    693    Gpay       2

# %%
##This groups the DataFrame data by the unique values in the 'City' column. It doesn't perform any computation on its own it is used for further operation
data.groupby('City')

# %%
##first it will group the data by unique values in city then it will sum all values in them
data.groupby('City').sum()
# Out:
#            Invoice ID                                               Date  \
# City
# Chicago  164244758326  3/19/20182/25/20183/4/20181/18/20183/7/20183/2...
# Dallas   160721744770  1/22/20182/18/20183/8/20181/18/20182/24/20183/...
# NewYork  169526550245  1/25/20183/9/20182/26/20183/21/20182/15/20182/...
#
#                                                       Time  \
# City
# Chicago  16:4813:3313:2115:2012:5010:1115:0211:5715:571...
# Dallas   13:3815:3113:2415:3316:0512:1211:1218:1816:081...
# NewYork  16:4617:5511:3213:2315:4715:5910:5819:4819:311...
#
#                                                     Gender  \
# City
# Chicago  FemaleMaleMaleFemaleMaleMaleMaleMaleMaleFemale...
# Dallas   FemaleFemaleMaleMaleFemaleMaleMaleMaleFemaleFe...
# NewYork  MaleMaleFemaleFemaleFemaleFemaleFemaleFemaleFe...
#
#                                                   Location  \
# City
# Chicago  Water towerWater towerWater towerWater towerWa...
# ...

# %%
##After performing sum() then we searched for particular column Named 'Total'
data.groupby('City').sum()['Total']
# Out:
# City
# Chicago    65215
# Dallas     70432
# NewYork    72141
# Name: Total, dtype: int64

# %%
##We Group the data with respect to member column
data.groupby('Member').sum()
# Out:
#           Invoice ID                                               Date  \
# Member
# No      242503049716  2/25/20182/18/20183/4/20183/8/20182/24/20182/2...
# Yes     251990003625  1/25/20183/19/20181/22/20183/9/20181/18/20181/...
#
#                                                      Time  \
# Member
# No      13:3315:3113:2113:2416:0511:3212:1211:1213:231...
# Yes     16:4616:4813:3817:5515:3315:2015:4715:5918:181...
#
#                                                    Gender  \
# Member
# No      MaleFemaleMaleMaleFemaleFemaleMaleMaleFemaleMa...
# Yes     MaleFemaleFemaleMaleMaleFemaleFemaleFemaleMale...
#
#                                                  Location  \
# Member
# No      Water towerPark laneWater towerPark lanePark l...
# Yes     BrookfieldWater towerPark laneBrookfieldPark l...
#
#                                                      City  \
# Member
# No      ChicagoDallasChicagoDallasDallasNewYorkDallasD...
# ...

# %%
##We searched a total number of members who said yes or no
data.groupby('Member').sum()['Total']
# Out:
# Member
# No     100245
# Yes    107543
# Name: Total, dtype: int64

# %%
##Continue
